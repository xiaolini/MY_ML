# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plot_x = np.linspace(-1, 6, 141)

# %%
plot_y = (plot_x - 2.5) ** 2 - 1

# %%
plt.plot(plot_x, plot_y)
plt.xlabel("theta")
plt.ylabel("J")
plt.show()

# %%
def dJ(theta):
    return 2 * (theta - 2.5)

# %%
def J(theta):
    return (theta - 2.5) ** 2 - 1

# %%
theta = 0.0
eta = 0.1
threshold = 1e-8
while True:
    gradient = dJ(theta)
    last_theta = theta
    theta = theta - eta * gradient
    if abs(J(theta) - J(last_theta)) < 1e-8:
        break
        
print(theta)
print(J(theta))
# Out:
# 2.499891109642585
# -0.99999998814289

# %%
def gradient_descent(initial_theta, eta, epsilon=1e-8):    
    theta = initial_theta
    theta_history.append(initial_theta)
    while True:
        gradient = dJ(theta)
        last_theta = theta
        theta = theta - eta * gradient
        theta_history.append(theta)
        if abs(J(theta) - J(last_theta)) < epsilon:
            break

#     print(theta)
#     print(J(theta))

def plot_theta_history():
    plt.plot(plot_x, J(plot_x), color='blue')
    # plt.plot(np.array(theta_history), np.array([J(theta) for theta in theta_history]), color='red', marker='+')
    plt.plot(np.array(theta_history), J(np.array(theta_history)), color='red', marker='+')
    plt.show()

# %%
len(theta_history)
# Out:
# 0

# %%
eta = 0.01
theta_history = []
gradient_descent(0.0, eta)
plot_theta_history()
print(len(theta_history))
# Out:
# 424

# %%
eta = 0.001
theta_history = []
gradient_descent(0.0, eta)
plot_theta_history()
print(len(theta_history))
# Out:
# 3682

# %%
eta = 0.8
theta_history = []
gradient_descent(0.0, eta)
plot_theta_history()
print(len(theta_history))
# Out:
# 22

# %%
eta = 1.1
theta_history = []
gradient_descent(0.0, eta)
plot_theta_history()
print(len(theta_history))
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-30-21580b250106> in <module>
#       1 eta = 1.1
#       2 theta_history = []
# ----> 3 gradient_descent(0.0, eta)
#       4 plot_theta_history()
#       5 print(len(theta_history))
#
# <ipython-input-22-3099d3a07bb1> in gradient_descent(initial_theta, eta, epsilon)
#       7         theta = theta - eta * gradient
#       8         theta_history.append(theta)
# ----> 9         if abs(J(theta) - J(last_theta)) < epsilon:
#      10             break
#      11
#
# <ipython-input-6-bd41aa589cfc> in J(theta)
#       1 def J(theta):
# ----> 2     return (theta - 2.5) ** 2 - 1
#
# OverflowError: (34, 'Numerical result out of range')

# %%
def J(theta):
    try:
        return (theta - 2.5) ** 2 - 1
    except:
        return float("inf")

# %%
def gradient_descent(initial_theta, eta, n_iters=1e4, epsilon=1e-8):    
    theta = initial_theta
    theta_history.append(initial_theta)
    i_iter = 0
    while i_iter < n_iters:        
        gradient = dJ(theta)
        last_theta = theta
        theta = theta - eta * gradient
        theta_history.append(theta)
        if abs(J(theta) - J(last_theta)) < epsilon:
            break
        i_iter += 1

#     print(theta)
#     print(J(theta))

def plot_theta_history():
    plt.plot(plot_x, J(plot_x), color='blue')
    # plt.plot(np.array(theta_history), np.array([J(theta) for theta in theta_history]), color='red', marker='+')
    plt.plot(np.array(theta_history), J(np.array(theta_history)), color='red', marker='+')
    plt.show()

# %%
eta = 1.1
theta_history = []
gradient_descent(0.0, eta, n_iters=10)
plot_theta_history()
print(len(theta_history))
# Out:
# 11
